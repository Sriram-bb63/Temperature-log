# %%
import pandas as pd

df = pd.read_csv("temp_log.csv")

df.head()
# Out:
#    Unnamed: 0                      time  package_id  core_0  core_1  \
# 0           0  Tue Nov 23 22:27:28 2021        59.0    59.0    44.0
# 1           1  Tue Nov 23 22:27:33 2021        45.0    42.0    43.0
# 2           2  Tue Nov 23 22:27:38 2021        46.0    41.0    42.0
# 3           3  Tue Nov 23 22:27:43 2021        46.0    42.0    45.0
# 4           4  Tue Nov 23 22:27:48 2021        45.0    41.0    43.0
#
#          ram  fan
# 0  25.073238    0
# 1  25.087173    0
# 2  25.054869    0
# 3  25.508391    0
# 4  28.195424    0

# %%
df = df[["time", "package_id", "core_0", "core_1", "ram", "fan"]]
df["time"] = df["time"].apply(lambda x: x[11:19])
df.head()
# Out:
#        time  package_id  core_0  core_1        ram  fan
# 0  22:27:28        59.0    59.0    44.0  25.073238    0
# 1  22:27:33        45.0    42.0    43.0  25.087173    0
# 2  22:27:38        46.0    41.0    42.0  25.054869    0
# 3  22:27:43        46.0    42.0    45.0  25.508391    0
# 4  22:27:48        45.0    41.0    43.0  28.195424    0

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %% [markdown]
# # Change ``n`` value in the cell below if the ticks on the x-axis of the graph produced are too congested.
#
# ## Increase/decrease ``n`` to decongest/congest x-axis ticks.

# %%
n = 10

# %%
plt.plot(df["time"], df["package_id"], label="package_id", color="black")
plt.plot(df["time"], df["core_0"], label="core_0", color="blue")
plt.plot(df["time"], df["core_1"], label="core_1", color="red")
plt.plot(df["time"], df["ram"], label="RAM", color="green")
plt.xlabel("Time")
plt.ylabel("Temp in C / RAM %")
plt.xticks(rotation="vertical")
ax = plt.gca()
ax.set_xticks(ax.get_xticks()[::n])
plt.legend(loc="upper left")
plt.show()

# %%
plt.plot(df["time"], df["fan"], label="RAM", color="green")
plt.xlabel("Time")
plt.ylabel("RPM")
plt.xticks(rotation="vertical")
plt.legend(loc="upper left")
ax = plt.gca()
ax.set_xticks(ax.get_xticks()[::n])
plt.show()
