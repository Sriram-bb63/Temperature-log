# %%
import pandas as pd

df = pd.read_csv("temp_log_sample.csv")
df.head()
# Out:
#        time  package_id  core_0  core_1    ram   fan
# 0  13:19:17        76.0    76.0    73.0  75.51  2521
# 1  13:19:22        58.0    55.0    57.0  77.38  2521
# 2  13:19:27        52.0    48.0    51.0  76.61  2525
# 3  13:19:32        57.0    53.0    57.0  77.45  2519
# 4  13:19:37        52.0    48.0    52.0  77.38  2521

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (30,10)

# %% [markdown]
# # Change ``n`` value in the cell below if the ticks on the x-axis of the graph produced are too congested.
#
# ## Increase/decrease ``n`` to decongest/congest x-axis ticks.

# %%
n = 1

# %%
plt.plot(df["time"], df["package_id"], label="package_id", color="black")
plt.plot(df["time"], df["core_0"], label="core_0", color="blue")
plt.plot(df["time"], df["core_1"], label="core_1", color="red")
plt.plot(df["time"], df["ram"], label="RAM", color="green")

plt.xlabel("Time")
plt.ylabel("Temp in C / RAM %")

plt.xticks(rotation="vertical")
ax = plt.gca()
ax.set_xticks(ax.get_xticks()[::n])
ax.set_ylim(bottom=0, top=100)
plt.legend(loc="upper left")

plt.show()

# %%
df["fan"]
# Out:
# 0    2521
# 1    2521
# 2    2525
# 3    2519
# 4    2521
# 5    2524
# 6    2519
# Name: fan, dtype: int64

# %%
plt.plot(df["time"], df["fan"], label="Fan rpm")

plt.xlabel("Time")
plt.ylabel("RPM")

plt.xticks(rotation="vertical")
plt.legend(loc="upper left")
ax = plt.gca()
ax.set_xticks(ax.get_xticks()[::n])

plt.show()
