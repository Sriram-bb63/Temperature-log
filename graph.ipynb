# %%
import pandas as pd

df = pd.read_csv("temp_log.csv")

df.head()
# Out:
#    Unnamed: 0                      time  package_id  core_0  core_1
# 0           0  Thu Nov 18 17:07:07 2021        72.0    51.0    72.0
# 1           1  Thu Nov 18 17:07:09 2021        49.0    44.0    48.0
# 2           2  Thu Nov 18 17:07:11 2021        49.0    45.0    48.0
# 3           3  Thu Nov 18 17:07:13 2021        49.0    45.0    48.0
# 4           4  Thu Nov 18 17:07:15 2021        49.0    45.0    48.0

# %%
df = df[["time", "package_id", "core_0", "core_1"]]

df.head()
# Out:
#                        time  package_id  core_0  core_1
# 0  Thu Nov 18 17:07:07 2021        72.0    51.0    72.0
# 1  Thu Nov 18 17:07:09 2021        49.0    44.0    48.0
# 2  Thu Nov 18 17:07:11 2021        49.0    45.0    48.0
# 3  Thu Nov 18 17:07:13 2021        49.0    45.0    48.0
# 4  Thu Nov 18 17:07:15 2021        49.0    45.0    48.0

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

plt.plot(df["time"], df["package_id"], label="package_id", color="black")
plt.plot(df["time"], df["core_0"], label="core_0", color="blue")
plt.plot(df["time"], df["core_1"], label="core_1", color="red")
plt.xlabel("Time")
plt.ylabel("Temperature in C")
plt.legend()
plt.show()
