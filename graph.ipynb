# %%
import pandas as pd

df = pd.read_csv("temp_log.csv")

df.head()
# Out:
#    Unnamed: 0                      time  package_id  core_0  core_1  \
# 0           0  Tue Nov 23 18:23:34 2021        65.0    47.0    65.0
# 1           1  Tue Nov 23 18:23:39 2021        51.0    46.0    47.0
# 2           2  Tue Nov 23 18:23:44 2021        51.0    46.0    48.0
# 3           3  Tue Nov 23 18:23:49 2021        50.0    46.0    48.0
# 4           4  Tue Nov 23 18:23:54 2021        51.0    46.0    47.0
#
#          ram   fan
# 0  72.647962  2543
# 1  73.358754  2547
# 2  72.737695  2547
# 3  73.305653  2547
# 4  72.606896  2547

# %%
df = df[["time", "package_id", "core_0", "core_1", "ram", "fan"]]

df.head()
# Out:
#                        time  package_id  core_0  core_1        ram   fan
# 0  Tue Nov 23 18:23:34 2021        65.0    47.0    65.0  72.647962  2543
# 1  Tue Nov 23 18:23:39 2021        51.0    46.0    47.0  73.358754  2547
# 2  Tue Nov 23 18:23:44 2021        51.0    46.0    48.0  72.737695  2547
# 3  Tue Nov 23 18:23:49 2021        50.0    46.0    48.0  73.305653  2547
# 4  Tue Nov 23 18:23:54 2021        51.0    46.0    47.0  72.606896  2547

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

plt.plot(df["time"], df["package_id"], label="package_id", color="black")
plt.plot(df["time"], df["core_0"], label="core_0", color="blue")
plt.plot(df["time"], df["core_1"], label="core_1", color="red")
plt.xlabel("Time")
plt.ylabel("Temperature in C")
plt.legend()
plt.show()

# %%
plt.plot(df["time"], df["ram"], label="RAM", color="green")
plt.xlabel("Time")
plt.ylabel("RAM used in %")
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(df["time"], df["fan"], label="RAM", color="green")
plt.xlabel("Time")
plt.ylabel("RPM")
plt.legend()
plt.grid()
plt.show()
